# %% [markdown]
# <a href="https://colab.research.google.com/github/JhanisYPS/ImersaoAluraProject/blob/main/ImersaoAlura_SCodex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INTRODUÇÃO**
# ---
#
# Este projeto possui única e exclusivamente fins de estudo e desenvolvimento de portfólio, além de aplicação e participação na competição da imersão da Alura em parceria com a Google. Eu sou dev júnior, contudo decidi utilizar somente as ferramentas passadas durante a imersão neste desafio, meu objetivo é fazer o melhor projeto possível com os recursos de aula e materiais complementares da própria imersão. Espero que eu tenha atingido um nível minimamente satisfatório.
#
# ---
# # **OVERVIEW**
# ---
#
# Decidi sair totalmente da minha zona de conforto e explorar algo novo, minha carreira é em tech e engenharia biomédica, mas para provar o ponto de que os recursos ensinados podem ser aplicados em qualquer área escolhi desenvolver um site com assistência virtual voltada a consultoria de imagem, utilizando colorimetria e método Kibbe. Minha inspiração veio do filme As Patricinhas de Beverly Hills, onde há um guarda roupas virtual que foi o sonho de consumo de muitas meninas dos anos 2000, imaginei como seria  aquele guarda roupas com IA aplicada e me foquei nesse desenvolvimento.
#
# > ### **CRIANDO MARCA FICTÍCIA**
#
# Criar nome da marca, utilizando engenharia de prompt para obter o nome mais comercial possível, que alavanque o meu negócio com mais facilidade.
#
# > ##### **PROMPT – MÉTODO (FEW-SHOT PROMPTING)**
#
#
# **Prompt**
#
# ```
# Crie um nome para a minha marca, com um acrônimo interessante.
#
# Projeto: Automatização de tarefas SAP para o Gustavo
# Nome: Gustavo vai Logo: Gu!-Go!
# Obs: a logo soa como o nome google, referenciando um mecânismo de pesquisa e a forma faz alusão ao Yug!-Yoh!
#
# Projeto: Inteligência Artificial com capacidade de prever queima de peças
# Nome: Articificial Inteligence Systems Accounts
# Logo: AISA
# Obs: Nome grego mitológico, com lenda totalmente ligada a previsão, futuro e tempo, AISA é uma moira que corta o fio da via, ou seja o programa está prevendo o fim da vida de uma peça.
#
# Projeto: Assistente Virtual Financeiro
# Nome: Layout UI Gerencial Interface
# Logo: Luigi
# Obs: O nome da pessoa que iria utilizar o programa era Mário, então o assistente se chama Luigi, por conta do jogo Super Mario Bros.
#
# Projeto: Marca de construção de imagem, focada em colorimetria e método Kibbe para melhorar presença digital e maketing pessoal. A marca é focada ao público feminino. Remete ao cliente o sentimento de estar criando a sua melhor versão com o uso do serviço de assessoria de imagem. O nome da marca é extremamente comercial e atrai muita atenção nas redes sociais.
# Nome:
# Logo:
# Obs: inspiração veio do filme As Patricinhas de Beverly Hills, onde há um guarda roupas virtual que foi o sonho de consumo de muitas meninas dos anos 2000, imaginei como seria  aquele guarda roupas com IA aplicada.
# ```
#
# **Answer**
#
# ```
# Sugestões para a sua marca de assessoria de imagem:
# Opção 1:
# Nome: Style Codex (Código de Estilo)
# Acrônimo: SC / S-Code
# Logo: Um "S" estilizado que se transforma em um "C", formando um símbolo infinito ou um nó celta que representa a jornada de descoberta de estilo.
# Observação: O nome sugere um guia ou manual para estilo pessoal, enquanto o acrônimo é curto e memorável. A logo representa a transformação e o desenvolvimento contínuo do estilo pessoal.
# Opção 2:
# Nome: Mirror, Mirror (Espelho, Espelho)
# Acrônimo: M2
# Logo: Dois "M" espelhados que formam um desenho abstrato de um rosto ou um vestido.
# Observação: O nome é uma referência direta ao conto da Branca de Neve e remete à ideia de descobrir a sua melhor versão. O acrônimo é simples e fácil de lembrar.
# Opção 3:
# Nome: Bloom (Florescer)
# Acrônimo: Não aplicável
# Logo: Uma flor desabrochando com cores vibrantes.
# Observação: O nome transmite a ideia de crescimento e desenvolvimento pessoal, associado à beleza e ao florescimento da mulher. A logo representa a transformação e o poder feminino.
# Opção 4:
# Nome: Kaleidoscope Style (Estilo Caleidoscópio)
# Acrônimo: KS
# Logo: Um caleidoscópio estilizado com formas geométricas e cores vibrantes.
# Observação: O nome sugere a diversidade e a individualidade do estilo pessoal, assim como a beleza única de cada mulher. A logo representa a variedade e a criatividade na moda.
# Opção 5:
# Nome: Evolve You (Evolua Você)
# Acrônimo: EY
# Logo: Uma borboleta estilizada que representa a transformação e a evolução.
# Observação: O nome transmite a ideia de crescimento pessoal e empoderamento feminino. A logo simboliza a beleza e a liberdade da mulher que descobre o seu estilo único.
# Dica extra: Considere registrar o nome e o logotipo da sua marca para protegê-la legalmente.
#
# ```
# > **Escolha**
#
# Escolhi a opção 1, embora as outras opções terem ficado muito boas também. Observem que o modelo deu uma “alucinada”, pois ele me deu uma resposta diferente dos meus exemplos, porém neste caso foi positivo, pois realmente ficou melhor do que o meu modelo proposto.
#
# > **Logo**
#
# O Gemini 1.5 Pro não é capaz de gerar imagens, apenas interpreta-lás. Sendo assim, utilizei o [DeepAI](https://deepai.org/) para criar uma imagem de logo. Sendo o prompt a descrição de logo do Gemini.
#
# **Prompt**
# ```
# Logo: Um "S" estilizado que se transforma em um "C", formando um símbolo infinito ou um nó celta que representa a jornada de descoberta de estilo.
#
# Observação: O nome sugere um guia ou manual para estilo pessoal, enquanto o acrônimo é curto e memorável. A logo representa a transformação e o desenvolvimento contínuo do estilo pessoal.
# ```
# **Answer**
#
# ![SC_Logo2.jfif](data:image/jpeg;base64,...)
